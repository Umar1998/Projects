# %% [markdown]
# # importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture

# %% [markdown]
# ## Loading the dataset into a pandas dataframe

# %%
df = pd.read_csv('seeds_dataset.txt', names=["data"])
df
# Out:
#                                                   data
# 0    15.26\t14.84\t0.871\t5.763\t3.312\t2.221\t5.22\t1
# 1    14.88\t14.57\t0.8811\t5.554\t3.333\t1.018\t4.9...
# 2    14.29\t14.09\t0.905\t5.291\t3.337\t2.699\t4.82...
# 3    13.84\t13.94\t0.8955\t5.324\t3.379\t2.259\t4.8...
# 4    16.14\t14.99\t0.9034\t5.658\t3.562\t1.355\t5.1...
# ..                                                 ...
# 205  12.19\t13.2\t0.8783\t5.137\t2.981\t3.631\t4.87\t3
# 206  11.23\t12.88\t0.8511\t5.14\t2.795\t4.325\t5.00...
# 207  13.2\t13.66\t0.8883\t5.236\t3.232\t8.315\t5.05...
# 208  11.84\t13.21\t0.8521\t5.175\t2.836\t3.598\t5.0...
# 209  12.3\t13.34\t0.8684\t5.243\t2.974\t5.637\t5.06...
#
# [210 rows x 1 columns]

# %% [markdown]
# **Various features of a particular data point is tab spaceed in each row, so splitting it.**

# %%
df=df.data.apply(lambda x: pd.Series(str(x).split("\t")))
df.head()
# Out:
#        0      1       2      3      4      5      6  7
# 0  15.26  14.84   0.871  5.763  3.312  2.221   5.22  1
# 1  14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 2  14.29  14.09   0.905  5.291  3.337  2.699  4.825  1
# 3  13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 4  16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       210 non-null    object
#  1   1       210 non-null    object
#  2   2       210 non-null    object
#  3   3       210 non-null    object
#  4   4       210 non-null    object
#  5   5       210 non-null    object
#  6   6       210 non-null    object
#  7   7       210 non-null    object
# dtypes: object(8)
# memory usage: 13.2+ KB

# %% [markdown]
# ## No we have to drop the 7th column of the dataframe, because it is the label of the data and we have to perform clustering.
#
# ### We will use the lables in later stages to compute the accuracy of our model.

# %%
data = df.drop([7], axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       210 non-null    object
#  1   1       210 non-null    object
#  2   2       210 non-null    object
#  3   3       210 non-null    object
#  4   4       210 non-null    object
#  5   5       210 non-null    object
#  6   6       210 non-null    object
# dtypes: object(7)
# memory usage: 11.6+ KB

# %%
# printing the first 10 rows of the data
data.head(10)
# Out:
#        0      1       2      3      4      5      6
# 0  15.26  14.84   0.871  5.763  3.312  2.221   5.22
# 1  14.88  14.57  0.8811  5.554  3.333  1.018  4.956
# 2  14.29  14.09   0.905  5.291  3.337  2.699  4.825
# 3  13.84  13.94  0.8955  5.324  3.379  2.259  4.805
# 4  16.14  14.99  0.9034  5.658  3.562  1.355  5.175
# 5  14.38  14.21  0.8951  5.386  3.312  2.462  4.956
# 6  14.69  14.49  0.8799  5.563  3.259  3.586  5.219
# 7  14.11   14.1  0.8911   5.42  3.302    2.7      5
# 8  16.63  15.46  0.8747  6.053  3.465   2.04  5.877
# 9  16.44  15.25   0.888  5.884  3.505  1.969  5.533

# %%
data = data.reset_index(drop = True)

# %%
data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       210 non-null    object
#  1   1       210 non-null    object
#  2   2       210 non-null    object
#  3   3       210 non-null    object
#  4   4       210 non-null    object
#  5   5       210 non-null    object
#  6   6       210 non-null    object
# dtypes: object(7)
# memory usage: 11.6+ KB
#          0      1       2      3      4      5      6
# 0    15.26  14.84   0.871  5.763  3.312  2.221   5.22
# 1    14.88  14.57  0.8811  5.554  3.333  1.018  4.956
# 2    14.29  14.09   0.905  5.291  3.337  2.699  4.825
# 3    13.84  13.94  0.8955  5.324  3.379  2.259  4.805
# 4    16.14  14.99  0.9034  5.658  3.562  1.355  5.175
# ..     ...    ...     ...    ...    ...    ...    ...
# 205  12.19   13.2  0.8783  5.137  2.981  3.631   4.87
# 206  11.23  12.88  0.8511   5.14  2.795  4.325  5.003
# 207   13.2  13.66  0.8883  5.236  3.232  8.315  5.056
# 208  11.84  13.21  0.8521  5.175  2.836  3.598  5.044
# 209   12.3  13.34  0.8684  5.243  2.974  5.637  5.063
#
# [210 rows x 7 columns]

# %%
# assigning the column names as mentioned on the source website of the data
data= data.rename({0 : 'area', 1 : 'perimeter ', 2 : 'compactness', 3 : 'length of kernel', 4 : 'width of kernel', 5 : 'asymmetry coefficient', 6 : 'length of kernel groove'}, axis=1)

# %%
data
# Out:
#       area perimeter  compactness length of kernel width of kernel  \
# 0    15.26      14.84       0.871            5.763           3.312
# 1    14.88      14.57      0.8811            5.554           3.333
# 2    14.29      14.09       0.905            5.291           3.337
# 3    13.84      13.94      0.8955            5.324           3.379
# 4    16.14      14.99      0.9034            5.658           3.562
# ..     ...        ...         ...              ...             ...
# 205  12.19       13.2      0.8783            5.137           2.981
# 206  11.23      12.88      0.8511             5.14           2.795
# 207   13.2      13.66      0.8883            5.236           3.232
# 208  11.84      13.21      0.8521            5.175           2.836
# 209   12.3      13.34      0.8684            5.243           2.974
#
#     asymmetry coefficient length of kernel groove
# 0                   2.221                    5.22
# 1                   1.018                   4.956
# 2                   2.699                   4.825
# 3                   2.259                   4.805
# 4                   1.355                   5.175
# ..                    ...                     ...
# 205                 3.631                    4.87
# 206                 4.325                   5.003
# 207                 8.315                   5.056
# 208                 3.598                   5.044
# 209                 5.637                   5.063
#
# [210 rows x 7 columns]

# %% [markdown]
# #### Building our model

# %%
gmm = GaussianMixture(n_components=3)
gmm.fit(data)

#predictions from gmm
labels = gmm.predict(data)
frame = pd.DataFrame(data)
frame['cluster'] = labels

# %%
frame
# Out:
#       area perimeter  compactness length of kernel width of kernel  \
# 0    15.26      14.84       0.871            5.763           3.312
# 1    14.88      14.57      0.8811            5.554           3.333
# 2    14.29      14.09       0.905            5.291           3.337
# 3    13.84      13.94      0.8955            5.324           3.379
# 4    16.14      14.99      0.9034            5.658           3.562
# ..     ...        ...         ...              ...             ...
# 205  12.19       13.2      0.8783            5.137           2.981
# 206  11.23      12.88      0.8511             5.14           2.795
# 207   13.2      13.66      0.8883            5.236           3.232
# 208  11.84      13.21      0.8521            5.175           2.836
# 209   12.3      13.34      0.8684            5.243           2.974
#
#     asymmetry coefficient length of kernel groove  cluster
# 0                   2.221                    5.22        2
# 1                   1.018                   4.956        2
# 2                   2.699                   4.825        2
# 3                   2.259                   4.805        2
# 4                   1.355                   5.175        2
# ..                    ...                     ...      ...
# 205                 3.631                    4.87        1
# 206                 4.325                   5.003        1
# 207                 8.315                   5.056        1
# 208                 3.598                   5.044        1
# 209                 5.637                   5.063        1
#
# [210 rows x 8 columns]

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   area                     210 non-null    object
#  1   perimeter                210 non-null    object
#  2   compactness              210 non-null    object
#  3   length of kernel         210 non-null    object
#  4   width of kernel          210 non-null    object
#  5   asymmetry coefficient    210 non-null    object
#  6   length of kernel groove  210 non-null    object
#  7   cluster                  210 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 13.2+ KB

# %%
# orignal labels(true_labels)
y_true = df.iloc[:, 7]
y_true
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 205    3
# 206    3
# 207    3
# 208    3
# 209    3
# Name: 7, Length: 210, dtype: object

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_true, frame['cluster'])
print("Accuracy score is", acc)
# Out:
# Accuracy score is 0.0

# %% [markdown]
# **The above cell is giving a very low accuracy score because:**
#
# Even though the clusters could match almost perfectly to the original labels, their labels might be permuted because of the model own assignment of cluster ID.
#
# So I am going to select randomly one point from each cluster and check their labels from the original data labels. Then we use this label for the whole cluster. Basically, we are ***renaming*** the clusters, ***not re-clustering*** the data.

# %%
import scipy
def find_permutation(n_clusters, real_labels, labels):
    permutation=[]
    for i in range(n_clusters):
        idx = labels == i
        new_label=scipy.stats.mode(real_labels[idx])[0][0]  # Choose the most common label among data points in the cluster
        permutation.append(new_label)
    return permutation

# %%
permutation = find_permutation(3, y_true, frame['cluster'])
print(permutation)
# Out:
# ['2', '3', '1']

# %%
new_labels = [ permutation[label] for label in labels]   # permute the labels
print("Accuracy score is", accuracy_score(y_true, new_labels))
Error_score = 1-accuracy_score(y_true, new_labels)
print("Error score is", Error_score)
# Out:
# Accuracy score is 0.8428571428571429
# Error score is 0.15714285714285714

# %% [markdown]
# ### Now in the above cell we can see that after adjusting the cluster Id's through permutation we get a very nice accuracy score of almost 92%.

# %%
# adding the new_labels column to the orignal dataframe in order to compare the cluster_id to the orignal labels
df['new_labels'] = new_labels
df.head(50)
# Out:
#         0      1       2      3      4       5      6  7 new_labels
# 0   15.26  14.84   0.871  5.763  3.312   2.221   5.22  1          1
# 1   14.88  14.57  0.8811  5.554  3.333   1.018  4.956  1          1
# 2   14.29  14.09   0.905  5.291  3.337   2.699  4.825  1          1
# 3   13.84  13.94  0.8955  5.324  3.379   2.259  4.805  1          1
# 4   16.14  14.99  0.9034  5.658  3.562   1.355  5.175  1          1
# 5   14.38  14.21  0.8951  5.386  3.312   2.462  4.956  1          1
# 6   14.69  14.49  0.8799  5.563  3.259   3.586  5.219  1          1
# 7   14.11   14.1  0.8911   5.42  3.302     2.7      5  1          1
# 8   16.63  15.46  0.8747  6.053  3.465    2.04  5.877  1          1
# 9   16.44  15.25   0.888  5.884  3.505   1.969  5.533  1          1
# 10  15.26  14.85  0.8696  5.714  3.242   4.543  5.314  1          1
# 11  14.03  14.16  0.8796  5.438  3.201   1.717  5.001  1          1
# 12  13.89  14.02   0.888  5.439  3.199   3.986  4.738  1          1
# 13  13.78  14.06  0.8759  5.479  3.156   3.136  4.872  1          1
# 14  13.74  14.05  0.8744  5.482  3.114   2.932  4.825  1          1
# 15  14.59  14.28  0.8993  5.351  3.333   4.185  4.781  1          1
# 16  13.99  13.83  0.9183  5.119  3.383   5.234  4.781  1          1
# 17  15.69  14.75  0.9058  5.527  3.514   1.599  5.046  1          1
# 18   14.7  14.21  0.9153  5.205  3.466   1.767  4.649  1          1
# 19  12.72  13.57  0.8686  5.226  3.049   4.102  4.914  1          3
# 20  14.16   14.4  0.8584  5.658  3.129   3.072  5.176  1          1
# 21  14.11  14.26  0.8722   5.52  3.168   2.688  5.219  1          1
# 22  15.88   14.9  0.8988  5.618  3.507  0.7651  5.091  1          1
# 23  12.08  13.23  0.8664  5.099  2.936   1.415  4.961  1          3
# 24  15.01  14.76  0.8657  5.789  3.245   1.791  5.001  1          1
# 25  16.19  15.16  0.8849  5.833  3.421   0.903  5.307  1          1
# 26  13.02  13.76  0.8641  5.395  3.026   3.373  4.825  1          3
# 27  12.74  13.67  0.8564  5.395  2.956   2.504  4.869  1          3
# 28  14.11  14.18   0.882  5.541  3.221   2.754  5.038  1          1
# 29  13.45  14.02  0.8604  5.516  3.065   3.531  5.097  1          3
# 30  13.16  13.82  0.8662  5.454  2.975  0.8551  5.056  1          3
# 31  15.49  14.94  0.8724  5.757  3.371   3.412  5.228  1          1
# 32  14.09  14.41  0.8529  5.717  3.186    3.92  5.299  1          1
# 33  13.94  14.17  0.8728  5.585   3.15   2.124  5.012  1          1
# 34  15.05  14.68  0.8779  5.712  3.328   2.129   5.36  1          1
# 35  16.12     15     0.9  5.709  3.485    2.27  5.443  1          1
# 36   16.2  15.27  0.8734  5.826  3.464   2.823  5.527  1          1
# 37  17.08  15.38  0.9079  5.832  3.683   2.956  5.484  1          2
# 38   14.8  14.52  0.8823  5.656  3.288   3.112  5.309  1          1
# 39  14.28  14.17  0.8944  5.397  3.298   6.685  5.001  1          1
# 40  13.54  13.85  0.8871  5.348  3.156   2.587  5.178  1          3
# 41   13.5  13.85  0.8852  5.351  3.158   2.249  5.176  1          3
# 42  13.16  13.55  0.9009  5.138  3.201   2.461  4.783  1          3
# 43   15.5  14.86   0.882  5.877  3.396   4.711  5.528  1          1
# 44  15.11  14.54  0.8986  5.579  3.462   3.128   5.18  1          1
# 45   13.8  14.04  0.8794  5.376  3.155    1.56  4.961  1          1
# 46  15.36  14.76  0.8861  5.701  3.393   1.367  5.132  1          1
# 47  14.99  14.56  0.8883   5.57  3.377   2.958  5.175  1          1
# 48  14.79  14.52  0.8819  5.545  3.291   2.704  5.111  1          1
# 49  14.86  14.67  0.8676  5.678  3.258   2.129  5.351  1          1

# %%
df.tail(50)
# Out:
#          0      1       2      3      4      5      6  7 new_labels
# 160  12.54  13.67  0.8425  5.451  2.879  3.082  5.491  3          3
# 161  12.02  13.33  0.8503   5.35   2.81  4.271  5.308  3          3
# 162  12.05  13.41  0.8416  5.267  2.847  4.988  5.046  3          3
# 163  12.55  13.57  0.8558  5.333  2.968  4.419  5.176  3          3
# 164  11.14  12.79  0.8558  5.011  2.794  6.388  5.049  3          3
# 165   12.1  13.15  0.8793  5.105  2.941  2.201  5.056  3          3
# 166  12.44  13.59  0.8462  5.319  2.897  4.924   5.27  3          3
# 167  12.15  13.45  0.8443  5.417  2.837  3.638  5.338  3          3
# 168  11.35  13.12  0.8291  5.176  2.668  4.337  5.132  3          3
# 169  11.24     13  0.8359   5.09  2.715  3.521  5.088  3          3
# 170  11.02     13  0.8189  5.325  2.701  6.735  5.163  3          3
# 171  11.55   13.1  0.8455  5.167  2.845  6.715  4.956  3          3
# 172  11.27  12.97  0.8419  5.088  2.763  4.309      5  3          3
# 173   11.4  13.08  0.8375  5.136  2.763  5.588  5.089  3          3
# 174  10.83  12.96  0.8099  5.278  2.641  5.182  5.185  3          3
# 175   10.8  12.57   0.859  4.981  2.821  4.773  5.063  3          3
# 176  11.26  13.01  0.8355  5.186   2.71  5.335  5.092  3          3
# 177  10.74  12.73  0.8329  5.145  2.642  4.702  4.963  3          3
# 178  11.48  13.05  0.8473   5.18  2.758  5.876  5.002  3          3
# 179  12.21  13.47  0.8453  5.357  2.893  1.661  5.178  3          3
# 180  11.41  12.95   0.856   5.09  2.775  4.957  4.825  3          3
# 181  12.46  13.41  0.8706  5.236  3.017  4.987  5.147  3          3
# 182  12.19  13.36  0.8579   5.24  2.909  4.857  5.158  3          3
# 183  11.65  13.07  0.8575  5.108   2.85  5.209  5.135  3          3
# 184  12.89  13.77  0.8541  5.495  3.026  6.185  5.316  3          3
# 185  11.56  13.31  0.8198  5.363  2.683  4.062  5.182  3          3
# 186  11.81  13.45  0.8198  5.413  2.716  4.898  5.352  3          3
# 187  10.91   12.8  0.8372  5.088  2.675  4.179  4.956  3          3
# 188  11.23  12.82  0.8594  5.089  2.821  7.524  4.957  3          3
# 189  10.59  12.41  0.8648  4.899  2.787  4.975  4.794  3          3
# 190  10.93   12.8   0.839  5.046  2.717  5.398  5.045  3          3
# 191  11.27  12.86  0.8563  5.091  2.804  3.985  5.001  3          3
# 192  11.87  13.02  0.8795  5.132  2.953  3.597  5.132  3          3
# 193  10.82  12.83  0.8256   5.18   2.63  4.853  5.089  3          3
# 194  12.11  13.27  0.8639  5.236  2.975  4.132  5.012  3          3
# 195   12.8  13.47   0.886   5.16  3.126  4.873  4.914  3          3
# 196  12.79  13.53  0.8786  5.224  3.054  5.483  4.958  3          3
# 197  13.37  13.78  0.8849   5.32  3.128   4.67  5.091  3          3
# 198  12.62  13.67  0.8481   5.41  2.911  3.306  5.231  3          3
# 199  12.76  13.38  0.8964  5.073  3.155  2.828   4.83  3          3
# 200  12.38  13.44  0.8609  5.219  2.989  5.472  5.045  3          3
# 201  12.67  13.32  0.8977  4.984  3.135    2.3  4.745  3          3
# 202  11.18  12.72   0.868  5.009   2.81  4.051  4.828  3          3
# 203   12.7  13.41  0.8874  5.183  3.091  8.456      5  3          3
# 204  12.37  13.47  0.8567  5.204   2.96  3.919  5.001  3          3
# 205  12.19   13.2  0.8783  5.137  2.981  3.631   4.87  3          3
# 206  11.23  12.88  0.8511   5.14  2.795  4.325  5.003  3          3
# 207   13.2  13.66  0.8883  5.236  3.232  8.315  5.056  3          3
# 208  11.84  13.21  0.8521  5.175  2.836  3.598  5.044  3          3
# 209   12.3  13.34  0.8684  5.243  2.974  5.637  5.063  3          3

# %% [markdown]
# ## We can not visulaize clusters beacuse the dimension of the  individual data points is 6 which is  greater than 3,  and we can visualize any data in 3 dimenstions at most.
#
# > **So for the illustration purpose, I am going to do clustring again using only two features and then plot the clusters.**
#
# > **Orignal and full implementation is done above**

# %%
df_new = data.iloc[:, 4:6]
df_new
# Out:
#     width of kernel asymmetry coefficient
# 0             3.312                 2.221
# 1             3.333                 1.018
# 2             3.337                 2.699
# 3             3.379                 2.259
# 4             3.562                 1.355
# ..              ...                   ...
# 205           2.981                 3.631
# 206           2.795                 4.325
# 207           3.232                 8.315
# 208           2.836                 3.598
# 209           2.974                 5.637
#
# [210 rows x 2 columns]

# %%
gmm_new = GaussianMixture(n_components=3)
gmm_new.fit(df_new)

#predictions from gmm
labels_new = gmm_new.predict(df_new)
frame_new = pd.DataFrame(df_new)
frame_new['cluster'] = labels_new
frame_new.columns = ['width of kernel', 'asymmetry coefficient','cluster']

# %%
# plotting the clusters:
color=['blue','green','cyan']
for k in range(0,3):
    df_new = frame[frame["cluster"]==k]
    plt.scatter(df_new["width of kernel"],df_new["asymmetry coefficient"])
plt.show()
